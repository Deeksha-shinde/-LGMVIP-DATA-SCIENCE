# %% [markdown]
# # LGM-VIP Data Science Internship Programme
# ## Begineer Level Task 4: Image to Pencil Sketch with Python .
# ### Submitted by: Deeksha Shinde
#
# #### Task description:
# ##### We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %% [markdown]
# # Installing opencv

# %%
# !pip install opencv-python

# %% [markdown]
# # Importing Libraries

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading image

# %%
img = cv2.imread('D:/Obama.png')

# %%
plt.imshow(img)    #(rgb format picture)

# %% [markdown]
# # Converting image to B-G-R Format

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)      #(bgr format picture)

# %% [markdown]
# # Converting BGR - Grayscale

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %% [markdown]
# # Converting Grayscale to Inverse Grayscale

# %%
inv_img = cv2.bitwise_not(gray)
plt.imshow(inv_img)

# %% [markdown]
# # Adding Blur to the Inverse Grayscale

# %%
blurred_inv_img = cv2.GaussianBlur(inv_img, (21, 21), 0)
plt.imshow(blurred_inv_img)

# %% [markdown]
# # Converting Blurred Inverse Grayscale to Blurred Grayscale

# %%
blurred_gray_img = cv2.bitwise_not(blurred_inv_img)
plt.imshow(blurred_gray_img)

# %% [markdown]
# # Type-1:Built-in Function
# ### Pencil Sketch

# %%
pencil_sketch = cv2.divide(gray, blurred_gray_img, scale=256.0)
plt.imshow(pencil_sketch)

# %% [markdown]
# # # Type-2:User-Defined Function
# ### Pencil Sketch

# %%
def pencil_sketch(x, y):
    return cv2.divide(x, 255 - y, scale=256)

# %%
pencil_sketch=pencil_sketch(gray,blurred_inv_img)

plt.imshow(pencil_sketch)
